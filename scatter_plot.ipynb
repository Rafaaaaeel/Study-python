# %% [markdown]
# <a href="https://colab.research.google.com/github/Rafaaaaeel/Study-python/blob/main/scatter_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
base = pd.read_csv('trees.csv')
base.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-cfe1e3a68c6c> in <module>()
#       1 base = pd.read_csv('trees.csv')
#       2 base.head()
# ----> 3 plt.scattert(base.girth, base.volume, color = 'blue', facecolor = 'none', marker = '*')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'scattert'

# %%
# Grafico de dispersao considerando o volume e a dispersao

plt.scatter(base.Girth, base.Volume, color = 'blue', facecolor = 'none', marker = '*')
plt.title('Arvores')
plt.xlabel('Volume')
plt.ylabel('Circunferencia')
# Out:
# Text(0, 0.5, 'Circunferencia')

# %%
# Grafico de linha considernado o volume e o atributo "Girth"

plt.plot(base.Girth, base.Volume)
plt.title('Arvores')
plt.xlabel('Volume')
plt.ylabel('Circunferencia')
# Out:
# Text(0, 0.5, 'Circunferencia')

# %%
# Grafico de dispersao com 'afastamento' dos dados (jitter)

sns.regplot(base.Girth, base.Volume, data = base, x_jitter= 0.3, fit_reg = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
